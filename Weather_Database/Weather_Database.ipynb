# %%
# Import the dependencies.
import pandas as pd
import numpy as np
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Import the requests library.
import requests
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
# Import linear regression from the SciPy stats module.
from scipy.stats import linregress
# import gmaps
import gmaps
# Import the API key.
from config import weather_api_key
from config import gkey

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 769

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68355746dc15697c0fecdafdecf88a0b

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather['weather'][0]['description']

        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | nabire
# Processing Record 3 of Set 1 | mildura
# Processing Record 4 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 5 of Set 1 | ouahigouya
# Processing Record 6 of Set 1 | aklavik
# Processing Record 7 of Set 1 | port alfred
# Processing Record 8 of Set 1 | bolungarvik
# City not found. Skipping...
# Processing Record 9 of Set 1 | buariki
# City not found. Skipping...
# Processing Record 10 of Set 1 | dikson
# Processing Record 11 of Set 1 | ribeira grande
# Processing Record 12 of Set 1 | rock island
# Processing Record 13 of Set 1 | lebu
# Processing Record 14 of Set 1 | leh
# Processing Record 15 of Set 1 | algiers
# Processing Record 16 of Set 1 | laizhou
# Processing Record 17 of Set 1 | sorland
# Processing Record 18 of Set 1 | amapa
# Processing Record 19 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 20 of Set 1 | coihaique
# Processing Record 21 of Set 1 | vila velha
# Processing Record 22 of Set 1 | bayji
# Processing Record 23 of Set 1 | butaritari
# Processing Record 24 of Set 1 | east london
# Processing Record 25 of Set 1 | san quintin
# Processing Record 26 of Set 1 | punta arenas
# Processing Record 27 of Set 1 | georgetown
# Processing Record 28 of Set 1 | qaqortoq
# Processing Record 29 of Set 1 | jequitinhonha
# Processing Record 30 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 31 of Set 1 | goderich
# Processing Record 32 of Set 1 | bredasdorp
# Processing Record 33 of Set 1 | hermanus
# Processing Record 34 of Set 1 | qaanaaq
# Processing Record 35 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 36 of Set 1 | luderitz
# Processing Record 37 of Set 1 | catamarca
# Processing Record 38 of Set 1 | tsuruoka
# Processing Record 39 of Set 1 | tasiilaq
# Processing Record 40 of Set 1 | camalu
# Processing Record 41 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 42 of Set 1 | khatanga
# Processing Record 43 of Set 1 | dingle
# Processing Record 44 of Set 1 | hithadhoo
# Processing Record 45 of Set 1 | oswego
# Processing Record 46 of Set 1 | toliary
# City not found. Skipping...
# Processing Record 47 of Set 1 | domoni
# Processing Record 48 of Set 1 | rawson
# Processing Record 49 of Set 1 | bluff
# Processing Record 50 of Set 1 | ahipara
# Processing Record 1 of Set 2 | mataura
# Processing Record 2 of Set 2 | ushuaia
# Processing Record 3 of Set 2 | busselton
# Processing Record 4 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 2 | ninghai
# Processing Record 6 of Set 2 | thompson
# Processing Record 7 of Set 2 | behshahr
# Processing Record 8 of Set 2 | castro
# Processing Record 9 of Set 2 | surt
# Processing Record 10 of Set 2 | kanniyakumari
# Processing Record 11 of Set 2 | leningradskiy
# Processing Record 12 of Set 2 | mergui
# City not found. Skipping...
# Processing Record 13 of Set 2 | tsabong
# Processing Record 14 of Set 2 | pala
# Processing Record 15 of Set 2 | vaini
# Processing Record 16 of Set 2 | xining
# Processing Record 17 of Set 2 | quatre cocos
# Processing Record 18 of Set 2 | beringovskiy
# Processing Record 19 of Set 2 | hobart
# Processing Record 20 of Set 2 | kavieng
# Processing Record 21 of Set 2 | kapaa
# Processing Record 22 of Set 2 | espirito santo do pinhal
# Processing Record 23 of Set 2 | chavakkad
# Processing Record 24 of Set 2 | sangar
# Processing Record 25 of Set 2 | hilo
# Processing Record 26 of Set 2 | tokoroa
# Processing Record 27 of Set 2 | birao
# Processing Record 28 of Set 2 | cape town
# Processing Record 29 of Set 2 | whitehaven
# Processing Record 30 of Set 2 | ancud
# Processing Record 31 of Set 2 | port macquarie
# Processing Record 32 of Set 2 | panzhihua
# Processing Record 33 of Set 2 | atuona
# Processing Record 34 of Set 2 | tshane
# Processing Record 35 of Set 2 | puerto ayora
# Processing Record 36 of Set 2 | tucuman
# Processing Record 37 of Set 2 | norman wells
# Processing Record 38 of Set 2 | lagoa
# Processing Record 39 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 40 of Set 2 | korgen
# Processing Record 41 of Set 2 | san patricio
# Processing Record 42 of Set 2 | new norfolk
# Processing Record 43 of Set 2 | acarau
# Processing Record 44 of Set 2 | kaitangata
# Processing Record 45 of Set 2 | dalinghe
# City not found. Skipping...
# Processing Record 46 of Set 2 | kruisfontein
# Processing Record 47 of Set 2 | kasongo-lunda
# Processing Record 48 of Set 2 | qandala
# Processing Record 49 of Set 2 | gamba
# Processing Record 50 of Set 2 | nikolskoye
# Processing Record 1 of Set 3 | arraial do cabo
# Processing Record 2 of Set 3 | mount gambier
# Processing Record 3 of Set 3 | khromtau
# Processing Record 4 of Set 3 | sitka
# Processing Record 5 of Set 3 | erzin
# Processing Record 6 of Set 3 | phalombe
# Processing Record 7 of Set 3 | marsa matruh
# Processing Record 8 of Set 3 | mahina
# Processing Record 9 of Set 3 | nouadhibou
# Processing Record 10 of Set 3 | ajdabiya
# Processing Record 11 of Set 3 | havre-saint-pierre
# Processing Record 12 of Set 3 | thinadhoo
# Processing Record 13 of Set 3 | itarema
# Processing Record 14 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 15 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 16 of Set 3 | filingue
# Processing Record 17 of Set 3 | sukhobezvodnoye
# Processing Record 18 of Set 3 | tawkar
# City not found. Skipping...
# Processing Record 19 of Set 3 | villacarrillo
# Processing Record 20 of Set 3 | pontian kecil
# Processing Record 21 of Set 3 | saldanha
# Processing Record 22 of Set 3 | mar del plata
# Processing Record 23 of Set 3 | pacific grove
# Processing Record 24 of Set 3 | tacuarembo
# Processing Record 25 of Set 3 | severo-kurilsk
# Processing Record 26 of Set 3 | west plains
# Processing Record 27 of Set 3 | fortuna
# Processing Record 28 of Set 3 | cockburn town
# Processing Record 29 of Set 3 | faanui
# Processing Record 30 of Set 3 | victoria
# Processing Record 31 of Set 3 | krasnoselkup
# Processing Record 32 of Set 3 | guangyuan
# Processing Record 33 of Set 3 | chokurdakh
# Processing Record 34 of Set 3 | tuktoyaktuk
# Processing Record 35 of Set 3 | narsaq
# Processing Record 36 of Set 3 | makakilo city
# Processing Record 37 of Set 3 | sakhnovshchyna
# Processing Record 38 of Set 3 | grindavik
# Processing Record 39 of Set 3 | bengkulu
# Processing Record 40 of Set 3 | mareeba
# Processing Record 41 of Set 3 | jalingo
# Processing Record 42 of Set 3 | bilma
# Processing Record 43 of Set 3 | bethel
# Processing Record 44 of Set 3 | othonoi
# City not found. Skipping...
# Processing Record 45 of Set 3 | brooks
# Processing Record 46 of Set 3 | paraiso
# Processing Record 47 of Set 3 | coaldale
# Processing Record 48 of Set 3 | denpasar
# Processing Record 49 of Set 3 | beloha
# Processing Record 50 of Set 3 | barrow
# Processing Record 1 of Set 4 | kodiak
# Processing Record 2 of Set 4 | iracoubo
# Processing Record 3 of Set 4 | viligili
# City not found. Skipping...
# Processing Record 4 of Set 4 | port elizabeth
# Processing Record 5 of Set 4 | hasaki
# Processing Record 6 of Set 4 | pisco
# Processing Record 7 of Set 4 | kita
# Processing Record 8 of Set 4 | grand centre
# City not found. Skipping...
# Processing Record 9 of Set 4 | katsuura
# Processing Record 10 of Set 4 | kieta
# Processing Record 11 of Set 4 | puerto carreno
# Processing Record 12 of Set 4 | alberton
# Processing Record 13 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 14 of Set 4 | kozmodemyansk
# Processing Record 15 of Set 4 | iqaluit
# Processing Record 16 of Set 4 | talnakh
# Processing Record 17 of Set 4 | tessalit
# Processing Record 18 of Set 4 | san cristobal
# Processing Record 19 of Set 4 | dakar
# Processing Record 20 of Set 4 | velsk
# Processing Record 21 of Set 4 | caconda
# Processing Record 22 of Set 4 | kalianget
# Processing Record 23 of Set 4 | kavaratti
# Processing Record 24 of Set 4 | carnarvon
# Processing Record 25 of Set 4 | parrita
# Processing Record 26 of Set 4 | diamantino
# Processing Record 27 of Set 4 | port hedland
# Processing Record 28 of Set 4 | ilulissat
# Processing Record 29 of Set 4 | bahia honda
# Processing Record 30 of Set 4 | mantua
# Processing Record 31 of Set 4 | saint anthony
# Processing Record 32 of Set 4 | ahuimanu
# Processing Record 33 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 34 of Set 4 | yellowknife
# Processing Record 35 of Set 4 | monte redondo
# Processing Record 36 of Set 4 | kollam
# Processing Record 37 of Set 4 | zhangye
# Processing Record 38 of Set 4 | saint-pierre
# Processing Record 39 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 40 of Set 4 | arman
# Processing Record 41 of Set 4 | mama
# Processing Record 42 of Set 4 | shache
# Processing Record 43 of Set 4 | taseyevo
# Processing Record 44 of Set 4 | hami
# Processing Record 45 of Set 4 | smithers
# Processing Record 46 of Set 4 | jamestown
# Processing Record 47 of Set 4 | port blair
# Processing Record 48 of Set 4 | lompoc
# Processing Record 49 of Set 4 | raudeberg
# Processing Record 50 of Set 4 | muslyumovo
# Processing Record 1 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 2 of Set 5 | onverwacht
# Processing Record 3 of Set 5 | podor
# Processing Record 4 of Set 5 | dunedin
# Processing Record 5 of Set 5 | isangel
# Processing Record 6 of Set 5 | saint-philippe
# Processing Record 7 of Set 5 | presidencia roque saenz pena
# Processing Record 8 of Set 5 | guerrero negro
# Processing Record 9 of Set 5 | tiksi
# Processing Record 10 of Set 5 | aljezur
# Processing Record 11 of Set 5 | korla
# Processing Record 12 of Set 5 | la huacana
# Processing Record 13 of Set 5 | kahului
# Processing Record 14 of Set 5 | coahuayana
# Processing Record 15 of Set 5 | sibolga
# Processing Record 16 of Set 5 | barranca
# Processing Record 17 of Set 5 | aykhal
# Processing Record 18 of Set 5 | cidreira
# Processing Record 19 of Set 5 | inta
# Processing Record 20 of Set 5 | anadyr
# Processing Record 21 of Set 5 | silvia
# Processing Record 22 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 23 of Set 5 | olafsvik
# Processing Record 24 of Set 5 | mahon
# Processing Record 25 of Set 5 | avarua
# Processing Record 26 of Set 5 | provideniya
# Processing Record 27 of Set 5 | seoul
# Processing Record 28 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 29 of Set 5 | turukhansk
# Processing Record 30 of Set 5 | hudson bay
# Processing Record 31 of Set 5 | diplo
# Processing Record 32 of Set 5 | challapata
# Processing Record 33 of Set 5 | imphal
# Processing Record 34 of Set 5 | haines junction
# Processing Record 35 of Set 5 | ampanihy
# Processing Record 36 of Set 5 | saint george
# Processing Record 37 of Set 5 | natal
# Processing Record 38 of Set 5 | te anau
# Processing Record 39 of Set 5 | aztec
# Processing Record 40 of Set 5 | andra
# Processing Record 41 of Set 5 | platteville
# Processing Record 42 of Set 5 | lavrentiya
# Processing Record 43 of Set 5 | mahebourg
# Processing Record 44 of Set 5 | touros
# Processing Record 45 of Set 5 | srednekolymsk
# Processing Record 46 of Set 5 | paradwip
# City not found. Skipping...
# Processing Record 47 of Set 5 | cabo san lucas
# Processing Record 48 of Set 5 | esperance
# Processing Record 49 of Set 5 | saint joseph
# Processing Record 50 of Set 5 | baculin
# Processing Record 1 of Set 6 | glens falls
# Processing Record 2 of Set 6 | la ronge
# Processing Record 3 of Set 6 | poya
# Processing Record 4 of Set 6 | saint-augustin
# Processing Record 5 of Set 6 | hamilton
# Processing Record 6 of Set 6 | kapoeta
# Processing Record 7 of Set 6 | san joaquin
# Processing Record 8 of Set 6 | koutiala
# Processing Record 9 of Set 6 | bambous virieux
# Processing Record 10 of Set 6 | izalco
# Processing Record 11 of Set 6 | port hardy
# Processing Record 12 of Set 6 | vila franca do campo
# Processing Record 13 of Set 6 | lima
# Processing Record 14 of Set 6 | uribia
# Processing Record 15 of Set 6 | brookings
# Processing Record 16 of Set 6 | yuanping
# Processing Record 17 of Set 6 | klaksvik
# Processing Record 18 of Set 6 | ambulu
# Processing Record 19 of Set 6 | lumby
# Processing Record 20 of Set 6 | muhos
# Processing Record 21 of Set 6 | sechura
# Processing Record 22 of Set 6 | tezu
# Processing Record 23 of Set 6 | bandundu
# Processing Record 24 of Set 6 | takoradi
# Processing Record 25 of Set 6 | faya
# Processing Record 26 of Set 6 | clyde river
# Processing Record 27 of Set 6 | mitsamiouli
# Processing Record 28 of Set 6 | ponta delgada
# Processing Record 29 of Set 6 | poopo
# Processing Record 30 of Set 6 | nome
# Processing Record 31 of Set 6 | maneadero
# Processing Record 32 of Set 6 | albany
# Processing Record 33 of Set 6 | port lincoln
# Processing Record 34 of Set 6 | vanimo
# Processing Record 35 of Set 6 | wattens
# Processing Record 36 of Set 6 | katangli
# Processing Record 37 of Set 6 | ringebu
# Processing Record 38 of Set 6 | matveyevka
# Processing Record 39 of Set 6 | upernavik
# Processing Record 40 of Set 6 | orange cove
# Processing Record 41 of Set 6 | bubaque
# Processing Record 42 of Set 6 | belle glade
# Processing Record 43 of Set 6 | shestakovo
# Processing Record 44 of Set 6 | imbituba
# Processing Record 45 of Set 6 | okha
# Processing Record 46 of Set 6 | riobamba
# Processing Record 47 of Set 6 | lata
# Processing Record 48 of Set 6 | mirabad
# Processing Record 49 of Set 6 | tilichiki
# Processing Record 50 of Set 6 | wilmington
# Processing Record 1 of Set 7 | puta
# Processing Record 2 of Set 7 | kaeo
# Processing Record 3 of Set 7 | dores do indaia
# Processing Record 4 of Set 7 | patnos
# Processing Record 5 of Set 7 | lorengau
# Processing Record 6 of Set 7 | batagay-alyta
# Processing Record 7 of Set 7 | pocatello
# Processing Record 8 of Set 7 | pevek
# Processing Record 9 of Set 7 | ponta do sol
# Processing Record 10 of Set 7 | tagusao
# Processing Record 11 of Set 7 | chapais
# Processing Record 12 of Set 7 | ruatoria
# City not found. Skipping...
# Processing Record 13 of Set 7 | ailigandi
# Processing Record 14 of Set 7 | alekseyevka
# Processing Record 15 of Set 7 | salalah
# Processing Record 16 of Set 7 | kosh-agach
# Processing Record 17 of Set 7 | nchelenge
# Processing Record 18 of Set 7 | port-gentil
# Processing Record 19 of Set 7 | athabasca
# Processing Record 20 of Set 7 | broken hill
# Processing Record 21 of Set 7 | geraldton
# Processing Record 22 of Set 7 | yulara
# Processing Record 23 of Set 7 | parabel
# Processing Record 24 of Set 7 | freetown
# Processing Record 25 of Set 7 | taguatinga
# Processing Record 26 of Set 7 | belmonte
# Processing Record 27 of Set 7 | bafia
# Processing Record 28 of Set 7 | bone
# Processing Record 29 of Set 7 | dhidhdhoo
# Processing Record 30 of Set 7 | deputatskiy
# Processing Record 31 of Set 7 | vardo
# Processing Record 32 of Set 7 | kayerkan
# Processing Record 33 of Set 7 | usinsk
# Processing Record 34 of Set 7 | wahran
# City not found. Skipping...
# Processing Record 35 of Set 7 | mackay
# Processing Record 36 of Set 7 | wexford
# Processing Record 37 of Set 7 | pimentel
# Processing Record 38 of Set 7 | youghal
# Processing Record 39 of Set 7 | tuatapere
# Processing Record 40 of Set 7 | nhulunbuy
# Processing Record 41 of Set 7 | avera
# Processing Record 42 of Set 7 | muscat
# Processing Record 43 of Set 7 | ostrovnoy
# Processing Record 44 of Set 7 | acapulco
# Processing Record 45 of Set 7 | litovko
# Processing Record 46 of Set 7 | rocha
# Processing Record 47 of Set 7 | stornoway
# Processing Record 48 of Set 7 | cap malheureux
# Processing Record 49 of Set 7 | wuwei
# Processing Record 50 of Set 7 | lanxi
# Processing Record 1 of Set 8 | biak
# Processing Record 2 of Set 8 | tupiza
# Processing Record 3 of Set 8 | ulladulla
# Processing Record 4 of Set 8 | kloulklubed
# Processing Record 5 of Set 8 | nizhniy baskunchak
# Processing Record 6 of Set 8 | meulaboh
# Processing Record 7 of Set 8 | sangueya
# Processing Record 8 of Set 8 | verkhnyaya sinyachikha
# Processing Record 9 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 10 of Set 8 | samfya
# Processing Record 11 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 12 of Set 8 | mezen
# Processing Record 13 of Set 8 | wangqing
# Processing Record 14 of Set 8 | merauke
# Processing Record 15 of Set 8 | meadow lake
# Processing Record 16 of Set 8 | santa luzia
# Processing Record 17 of Set 8 | cabedelo
# Processing Record 18 of Set 8 | cape canaveral
# Processing Record 19 of Set 8 | pandan
# Processing Record 20 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 21 of Set 8 | urdoma
# Processing Record 22 of Set 8 | saskylakh
# Processing Record 23 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 24 of Set 8 | hambantota
# Processing Record 25 of Set 8 | huarmey
# Processing Record 26 of Set 8 | khormuj
# City not found. Skipping...
# Processing Record 27 of Set 8 | bay roberts
# Processing Record 28 of Set 8 | lazaro cardenas
# Processing Record 29 of Set 8 | pangnirtung
# Processing Record 30 of Set 8 | stephenville crossing
# Processing Record 31 of Set 8 | turkmenabat
# Processing Record 32 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 33 of Set 8 | hailey
# Processing Record 34 of Set 8 | ankazoabo
# Processing Record 35 of Set 8 | viedma
# Processing Record 36 of Set 8 | moree
# Processing Record 37 of Set 8 | gangapur
# Processing Record 38 of Set 8 | brigantine
# Processing Record 39 of Set 8 | jarjis
# City not found. Skipping...
# Processing Record 40 of Set 8 | grand island
# Processing Record 41 of Set 8 | nizhniy kuranakh
# Processing Record 42 of Set 8 | komsomolskiy
# Processing Record 43 of Set 8 | sibu
# Processing Record 44 of Set 8 | karratha
# Processing Record 45 of Set 8 | opuwo
# Processing Record 46 of Set 8 | boa vista
# Processing Record 47 of Set 8 | onega
# Processing Record 48 of Set 8 | ondo
# Processing Record 49 of Set 8 | bilibino
# Processing Record 50 of Set 8 | gijon
# Processing Record 1 of Set 9 | khorramshahr
# Processing Record 2 of Set 9 | koumac
# Processing Record 3 of Set 9 | dawlatabad
# Processing Record 4 of Set 9 | senneterre
# Processing Record 5 of Set 9 | kidal
# Processing Record 6 of Set 9 | tomatlan
# Processing Record 7 of Set 9 | la palma
# Processing Record 8 of Set 9 | sur
# Processing Record 9 of Set 9 | romitan
# Processing Record 10 of Set 9 | vestmannaeyjar
# Processing Record 11 of Set 9 | sao filipe
# Processing Record 12 of Set 9 | antalaha
# Processing Record 13 of Set 9 | kenora
# Processing Record 14 of Set 9 | lesnoy
# Processing Record 15 of Set 9 | axim
# Processing Record 16 of Set 9 | polyarnyy
# Processing Record 17 of Set 9 | kaili
# Processing Record 18 of Set 9 | ust-koksa
# Processing Record 19 of Set 9 | marawi
# Processing Record 20 of Set 9 | bom jesus
# Processing Record 21 of Set 9 | sarahan
# Processing Record 22 of Set 9 | dawei
# Processing Record 23 of Set 9 | airai
# Processing Record 24 of Set 9 | berlevag
# Processing Record 25 of Set 9 | promissao
# Processing Record 26 of Set 9 | kupang
# Processing Record 27 of Set 9 | sohag
# Processing Record 28 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 29 of Set 9 | bonavista
# Processing Record 30 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 31 of Set 9 | palauig
# Processing Record 32 of Set 9 | loukhi
# Processing Record 33 of Set 9 | boyolangu
# Processing Record 34 of Set 9 | innisfail
# Processing Record 35 of Set 9 | tura
# Processing Record 36 of Set 9 | maniitsoq
# Processing Record 37 of Set 9 | kumano
# Processing Record 38 of Set 9 | puerto cabello
# Processing Record 39 of Set 9 | salinas
# Processing Record 40 of Set 9 | kjollefjord
# Processing Record 41 of Set 9 | jega
# Processing Record 42 of Set 9 | whyalla
# Processing Record 43 of Set 9 | auki
# Processing Record 44 of Set 9 | siyabuswa
# Processing Record 45 of Set 9 | yomitan
# City not found. Skipping...
# Processing Record 46 of Set 9 | longyearbyen
# Processing Record 47 of Set 9 | kiunga
# Processing Record 48 of Set 9 | sakakah
# Processing Record 49 of Set 9 | ixtapa
# Processing Record 50 of Set 9 | naze
# Processing Record 1 of Set 10 | aniva
# Processing Record 2 of Set 10 | sao gabriel da cachoeira
# Processing Record 3 of Set 10 | beira
# Processing Record 4 of Set 10 | mahibadhoo
# Processing Record 5 of Set 10 | maki
# Processing Record 6 of Set 10 | constitucion
# Processing Record 7 of Set 10 | richards bay
# Processing Record 8 of Set 10 | boshnyakovo
# Processing Record 9 of Set 10 | kongolo
# Processing Record 10 of Set 10 | nantucket
# Processing Record 11 of Set 10 | general roca
# Processing Record 12 of Set 10 | shawville
# Processing Record 13 of Set 10 | sept-iles
# Processing Record 14 of Set 10 | druzhba
# Processing Record 15 of Set 10 | porto novo
# Processing Record 16 of Set 10 | saryshagan
# City not found. Skipping...
# Processing Record 17 of Set 10 | chateauroux
# Processing Record 18 of Set 10 | simao
# Processing Record 19 of Set 10 | namibe
# Processing Record 20 of Set 10 | luau
# Processing Record 21 of Set 10 | waipawa
# Processing Record 22 of Set 10 | shimoda
# Processing Record 23 of Set 10 | monrovia
# Processing Record 24 of Set 10 | puerto penasco
# Processing Record 25 of Set 10 | chernyshevskiy
# Processing Record 26 of Set 10 | bandarbeyla
# Processing Record 27 of Set 10 | mangrol
# Processing Record 28 of Set 10 | tahta
# Processing Record 29 of Set 10 | sistranda
# Processing Record 30 of Set 10 | belaya gora
# Processing Record 31 of Set 10 | nagpur
# Processing Record 32 of Set 10 | taua
# Processing Record 33 of Set 10 | comodoro rivadavia
# Processing Record 34 of Set 10 | alamosa
# Processing Record 35 of Set 10 | luebo
# Processing Record 36 of Set 10 | seydi
# Processing Record 37 of Set 10 | takaka
# Processing Record 38 of Set 10 | ozgon
# City not found. Skipping...
# Processing Record 39 of Set 10 | omsukchan
# Processing Record 40 of Set 10 | ferrol
# Processing Record 41 of Set 10 | okhotsk
# Processing Record 42 of Set 10 | torbay
# Processing Record 43 of Set 10 | taoudenni
# Processing Record 44 of Set 10 | loubomo
# Processing Record 45 of Set 10 | poum
# Processing Record 46 of Set 10 | los llanos de aridane
# Processing Record 47 of Set 10 | padang
# Processing Record 48 of Set 10 | henties bay
# Processing Record 49 of Set 10 | giyani
# Processing Record 50 of Set 10 | mathbaria
# Processing Record 1 of Set 11 | karkaralinsk
# City not found. Skipping...
# Processing Record 2 of Set 11 | sioux lookout
# Processing Record 3 of Set 11 | ayan
# Processing Record 4 of Set 11 | mount isa
# Processing Record 5 of Set 11 | alihe
# Processing Record 6 of Set 11 | flin flon
# Processing Record 7 of Set 11 | abay
# Processing Record 8 of Set 11 | lebedinyy
# Processing Record 9 of Set 11 | liwale
# Processing Record 10 of Set 11 | sataua
# City not found. Skipping...
# Processing Record 11 of Set 11 | benin
# Processing Record 12 of Set 11 | iralaya
# Processing Record 13 of Set 11 | lokken verk
# City not found. Skipping...
# Processing Record 14 of Set 11 | tallahassee
# Processing Record 15 of Set 11 | fredericton
# Processing Record 16 of Set 11 | banda aceh
# Processing Record 17 of Set 11 | sosnovo-ozerskoye
# Processing Record 18 of Set 11 | asayita
# City not found. Skipping...
# Processing Record 19 of Set 11 | laiyang
# Processing Record 20 of Set 11 | harper
# Processing Record 21 of Set 11 | ipixuna
# Processing Record 22 of Set 11 | ardmore
# Processing Record 23 of Set 11 | candawaga
# City not found. Skipping...
# Processing Record 24 of Set 11 | chabahar
# Processing Record 25 of Set 11 | colares
# Processing Record 26 of Set 11 | mullaitivu
# City not found. Skipping...
# Processing Record 27 of Set 11 | ulaangom
# Processing Record 28 of Set 11 | rio grande
# Processing Record 29 of Set 11 | morondava
# Processing Record 30 of Set 11 | yendi
# Processing Record 31 of Set 11 | hualmay
# Processing Record 32 of Set 11 | kedrovyy
# Processing Record 33 of Set 11 | carutapera
# Processing Record 34 of Set 11 | inirida
# Processing Record 35 of Set 11 | ilebo
# Processing Record 36 of Set 11 | hofn
# Processing Record 37 of Set 11 | tondon
# Processing Record 38 of Set 11 | aksu
# Processing Record 39 of Set 11 | seminole
# Processing Record 40 of Set 11 | hobyo
# Processing Record 41 of Set 11 | nelson
# Processing Record 42 of Set 11 | burnie
# Processing Record 43 of Set 11 | chesma
# Processing Record 44 of Set 11 | pueblo nuevo vinas
# Processing Record 45 of Set 11 | chifeng
# Processing Record 46 of Set 11 | sao felix do xingu
# Processing Record 47 of Set 11 | prescott
# Processing Record 48 of Set 11 | chincha alta
# Processing Record 49 of Set 11 | chuy
# Processing Record 50 of Set 11 | mayumba
# Processing Record 1 of Set 12 | comitancillo
# Processing Record 2 of Set 12 | prince rupert
# Processing Record 3 of Set 12 | mehran
# Processing Record 4 of Set 12 | imeni poliny osipenko
# Processing Record 5 of Set 12 | magaria
# Processing Record 6 of Set 12 | kedougou
# Processing Record 7 of Set 12 | izhma
# Processing Record 8 of Set 12 | sinnamary
# Processing Record 9 of Set 12 | ambodifototra
# City not found. Skipping...
# Processing Record 10 of Set 12 | labutta
# City not found. Skipping...
# Processing Record 11 of Set 12 | puerto vallarta
# Processing Record 12 of Set 12 | batemans bay
# Processing Record 13 of Set 12 | zheleznovodsk
# Processing Record 14 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 15 of Set 12 | lagunas
# Processing Record 16 of Set 12 | celestun
# Processing Record 17 of Set 12 | caldararu
# Processing Record 18 of Set 12 | weihe
# Processing Record 19 of Set 12 | mandalgovi
# Processing Record 20 of Set 12 | nanortalik
# Processing Record 21 of Set 12 | podyuga
# Processing Record 22 of Set 12 | coquimbo
# Processing Record 23 of Set 12 | soe
# Processing Record 24 of Set 12 | kanlagay
# Processing Record 25 of Set 12 | alofi
# Processing Record 26 of Set 12 | juba
# Processing Record 27 of Set 12 | caravelas
# Processing Record 28 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 29 of Set 12 | hermiston
# Processing Record 30 of Set 12 | bada
# Processing Record 31 of Set 12 | dicabisagan
# Processing Record 32 of Set 12 | piney green
# Processing Record 33 of Set 12 | manadhoo
# Processing Record 34 of Set 12 | dergachi
# Processing Record 35 of Set 12 | fleetwood
# Processing Record 36 of Set 12 | kenai
# Processing Record 37 of Set 12 | ossora
# Processing Record 38 of Set 12 | villa bruzual
# Processing Record 39 of Set 12 | mgandu
# Processing Record 40 of Set 12 | ndele
# Processing Record 41 of Set 12 | raduzhnyy
# Processing Record 42 of Set 12 | ambilobe
# Processing Record 43 of Set 12 | vao
# Processing Record 44 of Set 12 | arlit
# Processing Record 45 of Set 12 | dondo
# Processing Record 46 of Set 12 | omboue
# Processing Record 47 of Set 12 | springfield
# Processing Record 48 of Set 12 | nova soure
# Processing Record 49 of Set 12 | port augusta
# Processing Record 50 of Set 12 | bowen
# Processing Record 1 of Set 13 | rajkot
# Processing Record 2 of Set 13 | mandan
# Processing Record 3 of Set 13 | kondagaon
# Processing Record 4 of Set 13 | gravdal
# Processing Record 5 of Set 13 | kikwit
# Processing Record 6 of Set 13 | svetlaya
# Processing Record 7 of Set 13 | sidi ali
# Processing Record 8 of Set 13 | namatanai
# Processing Record 9 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 10 of Set 13 | one hundred mile house
# City not found. Skipping...
# Processing Record 11 of Set 13 | matara
# Processing Record 12 of Set 13 | tostamaa
# City not found. Skipping...
# Processing Record 13 of Set 13 | anloga
# Processing Record 14 of Set 13 | tommot
# Processing Record 15 of Set 13 | serdobsk
# Processing Record 16 of Set 13 | manaus
# Processing Record 17 of Set 13 | storforshei
# Processing Record 18 of Set 13 | mehamn
# Processing Record 19 of Set 13 | pueblo
# Processing Record 20 of Set 13 | opotiki
# Processing Record 21 of Set 13 | luanda
# Processing Record 22 of Set 13 | cocachacra
# Processing Record 23 of Set 13 | west wendover
# Processing Record 24 of Set 13 | ushtobe
# Processing Record 25 of Set 13 | garachine
# Processing Record 26 of Set 13 | bagan
# Processing Record 27 of Set 13 | leshukonskoye
# Processing Record 28 of Set 13 | awjilah
# Processing Record 29 of Set 13 | guiratinga
# Processing Record 30 of Set 13 | verkhnevilyuysk
# Processing Record 31 of Set 13 | lahaina
# Processing Record 32 of Set 13 | brae
# Processing Record 33 of Set 13 | bhuj
# Processing Record 34 of Set 13 | kaithal
# Processing Record 35 of Set 13 | traralgon
# Processing Record 36 of Set 13 | kintampo
# Processing Record 37 of Set 13 | port-cartier
# Processing Record 38 of Set 13 | komarikhinskiy
# Processing Record 39 of Set 13 | george
# Processing Record 40 of Set 13 | phangnga
# Processing Record 41 of Set 13 | pilar
# Processing Record 42 of Set 13 | labuhan
# Processing Record 43 of Set 13 | bambanglipuro
# Processing Record 44 of Set 13 | jablunkov
# Processing Record 45 of Set 13 | kisangani
# Processing Record 46 of Set 13 | watertown
# Processing Record 47 of Set 13 | bitlis
# Processing Record 48 of Set 13 | enshi
# Processing Record 49 of Set 13 | miri
# Processing Record 50 of Set 13 | roma
# Processing Record 1 of Set 14 | barddhaman
# Processing Record 2 of Set 14 | dabakala
# Processing Record 3 of Set 14 | pudozh
# Processing Record 4 of Set 14 | tigil
# Processing Record 5 of Set 14 | bathsheba
# Processing Record 6 of Set 14 | palmer
# Processing Record 7 of Set 14 | emirdag
# Processing Record 8 of Set 14 | neiafu
# Processing Record 9 of Set 14 | mutsamudu
# City not found. Skipping...
# Processing Record 10 of Set 14 | san buenaventura
# Processing Record 11 of Set 14 | khovu-aksy
# Processing Record 12 of Set 14 | nemuro
# Processing Record 13 of Set 14 | soyo
# Processing Record 14 of Set 14 | thayetmyo
# Processing Record 15 of Set 14 | gornyy
# Processing Record 16 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 17 of Set 14 | portland
# Processing Record 18 of Set 14 | svetlyy
# Processing Record 19 of Set 14 | la paz
# Processing Record 20 of Set 14 | roald
# Processing Record 21 of Set 14 | peniche
# Processing Record 22 of Set 14 | gort
# Processing Record 23 of Set 14 | bardiyah
# Processing Record 24 of Set 14 | uaua
# Processing Record 25 of Set 14 | tual
# Processing Record 26 of Set 14 | raypur
# Processing Record 27 of Set 14 | grand gaube
# Processing Record 28 of Set 14 | havoysund
# Processing Record 29 of Set 14 | bonthe
# Processing Record 30 of Set 14 | san ramon
# Processing Record 31 of Set 14 | kolondieba
# Processing Record 32 of Set 14 | batticaloa
# Processing Record 33 of Set 14 | andenes
# Processing Record 34 of Set 14 | maues
# Processing Record 35 of Set 14 | manta
# Processing Record 36 of Set 14 | mwense
# Processing Record 37 of Set 14 | asau
# Processing Record 38 of Set 14 | tabacao
# Processing Record 39 of Set 14 | chateau-thierry
# Processing Record 40 of Set 14 | murray bridge
# Processing Record 41 of Set 14 | vila
# Processing Record 42 of Set 14 | dong hoi
# Processing Record 43 of Set 14 | sisimiut
# Processing Record 44 of Set 14 | hornepayne
# Processing Record 45 of Set 14 | vostok
# Processing Record 46 of Set 14 | cururupu
# Processing Record 47 of Set 14 | wanning
# Processing Record 48 of Set 14 | rock springs
# Processing Record 49 of Set 14 | petropavl
# Processing Record 50 of Set 14 | salamiyah
# Processing Record 1 of Set 15 | kununurra
# Processing Record 2 of Set 15 | eganville
# Processing Record 3 of Set 15 | tabory
# Processing Record 4 of Set 15 | whitehorse
# Processing Record 5 of Set 15 | codrington
# Processing Record 6 of Set 15 | baherden
# Processing Record 7 of Set 15 | la rioja
# Processing Record 8 of Set 15 | benavente
# Processing Record 9 of Set 15 | oga
# Processing Record 10 of Set 15 | atar
# Processing Record 11 of Set 15 | kamenka
# Processing Record 12 of Set 15 | codajas
# Processing Record 13 of Set 15 | ormara
# Processing Record 14 of Set 15 | rayagada
# Processing Record 15 of Set 15 | samalaeulu
# City not found. Skipping...
# Processing Record 16 of Set 15 | souillac
# Processing Record 17 of Set 15 | manhattan
# Processing Record 18 of Set 15 | tautira
# Processing Record 19 of Set 15 | lasa
# Processing Record 20 of Set 15 | yerofey pavlovich
# Processing Record 21 of Set 15 | fairbanks
# Processing Record 22 of Set 15 | manicore
# Processing Record 23 of Set 15 | villa maria
# Processing Record 24 of Set 15 | adeje
# Processing Record 25 of Set 15 | havelock
# Processing Record 26 of Set 15 | shenjiamen
# Processing Record 27 of Set 15 | sambava
# Processing Record 28 of Set 15 | dinghai
# Processing Record 29 of Set 15 | medea
# Processing Record 30 of Set 15 | vietri sul mare
# Processing Record 31 of Set 15 | prabumulih
# Processing Record 32 of Set 15 | goedereede
# Processing Record 33 of Set 15 | qeshm
# Processing Record 34 of Set 15 | sainte-maxime
# Processing Record 35 of Set 15 | mitchell
# Processing Record 36 of Set 15 | fort nelson
# Processing Record 37 of Set 15 | mogadishu
# Processing Record 38 of Set 15 | kadoma
# Processing Record 39 of Set 15 | magistralnyy
# Processing Record 40 of Set 15 | bida
# Processing Record 41 of Set 15 | bitam
# Processing Record 42 of Set 15 | yusva
# City not found. Skipping...
# Processing Record 43 of Set 15 | khonuu
# City not found. Skipping...
# Processing Record 44 of Set 15 | bayanday
# Processing Record 45 of Set 15 | dudinka
# Processing Record 46 of Set 15 | makaryev
# Processing Record 47 of Set 15 | nkowakowa
# Processing Record 48 of Set 15 | banbury
# Processing Record 49 of Set 15 | consolacion del sur
# Processing Record 50 of Set 15 | catalina
# Processing Record 1 of Set 16 | ardistan
# City not found. Skipping...
# Processing Record 2 of Set 16 | randvere
# City not found. Skipping...
# Processing Record 3 of Set 16 | grindsted
# Processing Record 4 of Set 16 | coalinga
# Processing Record 5 of Set 16 | cherskiy
# Processing Record 6 of Set 16 | junin
# Processing Record 7 of Set 16 | krasnoyarsk-45
# City not found. Skipping...
# Processing Record 8 of Set 16 | martil
# Processing Record 9 of Set 16 | sobolevo
# Processing Record 10 of Set 16 | jaicos
# Processing Record 11 of Set 16 | rundu
# Processing Record 12 of Set 16 | praia da vitoria
# Processing Record 13 of Set 16 | bradley
# Processing Record 14 of Set 16 | pangani
# Processing Record 15 of Set 16 | umarga
# Processing Record 16 of Set 16 | muros
# Processing Record 17 of Set 16 | wewak
# Processing Record 18 of Set 16 | ridgecrest
# Processing Record 19 of Set 16 | aflu
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Aklavik  68.2191 -135.0107     -8.57        77          90
# 1       Talcahuano -36.7167  -73.1167     69.48        64           0
# 2  Bambous Virieux -20.3428   57.7575     74.21        88          20
# 3        Hithadhoo  -0.6000   73.0833     81.55        73         100
# 4         Flinders -34.5833  150.8552     84.06        60         100
# 5          Mataura -46.1927  168.8643     73.47        42          93
# 6      Yellowknife  62.4560 -114.3525    -13.59        95          75
# 7          Ushuaia -54.8000  -68.3000     64.06        45          20
# 8            Vaini -21.2000 -175.2000     84.36        94          40
# 9         Hamilton  39.1834  -84.5333     43.09        92         100
#
#    Wind Speed Country Current Description
# 0        0.00      CA          light snow
# 1       12.66      CL           clear sky
# 2        3.44      MU          few clouds
# 3        3.11      MV     overcast clouds
# 4        8.12      AU     overcast clouds
# 5       13.09      NZ     overcast clouds
# 6        4.61      CA   light shower snow
# 7       18.41      AR          few clouds
# 8        9.22      TO          light rain
# 9        4.00      US     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
