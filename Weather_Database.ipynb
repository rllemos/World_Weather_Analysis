# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Import the requests library.
import requests
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
# Import linear regression from the SciPy stats module.
from scipy.stats import linregress
# import gmaps
import gmaps
# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 786

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=68355746dc15697c0fecdafdecf88a0b

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# # Loop through all the cities in our list.
# for i in range(len(cities)):

#     # Group cities in sets of 50 for logging purposes.
#     if (i % 50 == 0 and i >= 50):
#         set_count += 1
#         record_count = 1
#         time.sleep(60)

#     # Create endpoint URL with each city.
#     city_url = url + "&q=" + cities[i]
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather['weather'][0]['description']

        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | aklavik
# Processing Record 2 of Set 1 | talcahuano
# Processing Record 3 of Set 1 | bambous virieux
# Processing Record 4 of Set 1 | hithadhoo
# Processing Record 5 of Set 1 | flinders
# Processing Record 6 of Set 1 | mataura
# Processing Record 7 of Set 1 | yellowknife
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | vaini
# Processing Record 10 of Set 1 | hamilton
# Processing Record 11 of Set 1 | sabya
# Processing Record 12 of Set 1 | bluff
# Processing Record 13 of Set 1 | mahebourg
# Processing Record 14 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 15 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 16 of Set 1 | lorengau
# Processing Record 17 of Set 1 | taburi
# City not found. Skipping...
# Processing Record 18 of Set 1 | sogdiondon
# City not found. Skipping...
# Processing Record 19 of Set 1 | semnan
# Processing Record 20 of Set 1 | new norfolk
# Processing Record 21 of Set 1 | albany
# Processing Record 22 of Set 1 | saint-georges
# Processing Record 23 of Set 1 | east london
# Processing Record 24 of Set 1 | faanui
# Processing Record 25 of Set 1 | jamestown
# Processing Record 26 of Set 1 | kang
# Processing Record 27 of Set 1 | coquimbo
# Processing Record 28 of Set 1 | vung tau
# Processing Record 29 of Set 1 | airai
# Processing Record 30 of Set 1 | atuona
# Processing Record 31 of Set 1 | dzilam gonzalez
# Processing Record 32 of Set 1 | kapaa
# Processing Record 33 of Set 1 | beloretsk
# Processing Record 34 of Set 1 | samarinda
# Processing Record 35 of Set 1 | cap malheureux
# Processing Record 36 of Set 1 | parfenyevo
# Processing Record 37 of Set 1 | samarai
# Processing Record 38 of Set 1 | port alfred
# Processing Record 39 of Set 1 | khatanga
# Processing Record 40 of Set 1 | swiecie
# Processing Record 41 of Set 1 | rikitea
# Processing Record 42 of Set 1 | villazon
# Processing Record 43 of Set 1 | taoudenni
# Processing Record 44 of Set 1 | yar-sale
# Processing Record 45 of Set 1 | saldanha
# Processing Record 46 of Set 1 | tocopilla
# Processing Record 47 of Set 1 | chagda
# City not found. Skipping...
# Processing Record 48 of Set 1 | rafraf
# Processing Record 49 of Set 1 | punta arenas
# Processing Record 50 of Set 1 | macaboboni
# City not found. Skipping...
# Processing Record 1 of Set 2 | santa cruz
# Processing Record 2 of Set 2 | bimbo
# Processing Record 3 of Set 2 | tecoanapa
# Processing Record 4 of Set 2 | kahului
# Processing Record 5 of Set 2 | ende
# Processing Record 6 of Set 2 | hobart
# Processing Record 7 of Set 2 | toftir
# City not found. Skipping...
# Processing Record 8 of Set 2 | coruripe
# Processing Record 9 of Set 2 | hermanus
# Processing Record 10 of Set 2 | busselton
# Processing Record 11 of Set 2 | bredasdorp
# Processing Record 12 of Set 2 | kisangani
# Processing Record 13 of Set 2 | svetlogorsk
# Processing Record 14 of Set 2 | port elizabeth
# Processing Record 15 of Set 2 | saint-augustin
# Processing Record 16 of Set 2 | avarua
# Processing Record 17 of Set 2 | akropong
# Processing Record 18 of Set 2 | camana
# Processing Record 19 of Set 2 | kodiak
# Processing Record 20 of Set 2 | zastron
# Processing Record 21 of Set 2 | ketchikan
# Processing Record 22 of Set 2 | olga
# Processing Record 23 of Set 2 | upernavik
# Processing Record 24 of Set 2 | boa vista
# Processing Record 25 of Set 2 | alofi
# Processing Record 26 of Set 2 | batticaloa
# Processing Record 27 of Set 2 | san quintin
# Processing Record 28 of Set 2 | mulki
# Processing Record 29 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 30 of Set 2 | necochea
# Processing Record 31 of Set 2 | lerwick
# Processing Record 32 of Set 2 | aleksandrovsk-sakhalinskiy
# Processing Record 33 of Set 2 | orichi
# Processing Record 34 of Set 2 | aquiraz
# Processing Record 35 of Set 2 | venado tuerto
# Processing Record 36 of Set 2 | butaritari
# Processing Record 37 of Set 2 | yerbogachen
# Processing Record 38 of Set 2 | bengkulu
# Processing Record 39 of Set 2 | sarangani
# Processing Record 40 of Set 2 | vanimo
# Processing Record 41 of Set 2 | torbay
# Processing Record 42 of Set 2 | thunder bay
# Processing Record 43 of Set 2 | beisfjord
# Processing Record 44 of Set 2 | ileza
# Processing Record 45 of Set 2 | shellbrook
# Processing Record 46 of Set 2 | florianopolis
# Processing Record 47 of Set 2 | mackenzie
# Processing Record 48 of Set 2 | daru
# Processing Record 49 of Set 2 | kloulklubed
# Processing Record 50 of Set 2 | cape town
# Processing Record 1 of Set 3 | clevelandia
# Processing Record 2 of Set 3 | arandis
# Processing Record 3 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 3 | winslow
# Processing Record 5 of Set 3 | pisco
# Processing Record 6 of Set 3 | ambovombe
# Processing Record 7 of Set 3 | cherskiy
# Processing Record 8 of Set 3 | yaan
# Processing Record 9 of Set 3 | rovaniemi
# Processing Record 10 of Set 3 | trairi
# Processing Record 11 of Set 3 | azimur
# City not found. Skipping...
# Processing Record 12 of Set 3 | fort nelson
# Processing Record 13 of Set 3 | wanaka
# Processing Record 14 of Set 3 | bandundu
# Processing Record 15 of Set 3 | esperance
# Processing Record 16 of Set 3 | husavik
# Processing Record 17 of Set 3 | vao
# Processing Record 18 of Set 3 | winneba
# Processing Record 19 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 20 of Set 3 | saint george
# Processing Record 21 of Set 3 | veraval
# Processing Record 22 of Set 3 | praia da vitoria
# Processing Record 23 of Set 3 | puerto ayora
# Processing Record 24 of Set 3 | olafsvik
# Processing Record 25 of Set 3 | longyearbyen
# Processing Record 26 of Set 3 | ribeira grande
# Processing Record 27 of Set 3 | aranos
# Processing Record 28 of Set 3 | chokurdakh
# Processing Record 29 of Set 3 | bratslav
# Processing Record 30 of Set 3 | thompson
# Processing Record 31 of Set 3 | bethel
# Processing Record 32 of Set 3 | nhulunbuy
# Processing Record 33 of Set 3 | shetpe
# Processing Record 34 of Set 3 | zaozerne
# Processing Record 35 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 36 of Set 3 | saskylakh
# Processing Record 37 of Set 3 | ostrovnoy
# Processing Record 38 of Set 3 | haimen
# Processing Record 39 of Set 3 | kaitangata
# Processing Record 40 of Set 3 | fairbanks
# Processing Record 41 of Set 3 | koumac
# Processing Record 42 of Set 3 | nikolskoye
# Processing Record 43 of Set 3 | kirillov
# Processing Record 44 of Set 3 | hami
# Processing Record 45 of Set 3 | horovice
# Processing Record 46 of Set 3 | barrow
# Processing Record 47 of Set 3 | hilo
# Processing Record 48 of Set 3 | broome
# Processing Record 49 of Set 3 | georgetown
# Processing Record 50 of Set 3 | kungurtug
# Processing Record 1 of Set 4 | cockburn town
# Processing Record 2 of Set 4 | santhia
# Processing Record 3 of Set 4 | arraial do cabo
# Processing Record 4 of Set 4 | krasne
# Processing Record 5 of Set 4 | lavrentiya
# Processing Record 6 of Set 4 | san vicente
# Processing Record 7 of Set 4 | qaanaaq
# Processing Record 8 of Set 4 | morant bay
# Processing Record 9 of Set 4 | takoradi
# Processing Record 10 of Set 4 | tromso
# Processing Record 11 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 4 | cayenne
# Processing Record 13 of Set 4 | malwan
# City not found. Skipping...
# Processing Record 14 of Set 4 | egvekinot
# Processing Record 15 of Set 4 | bagdarin
# Processing Record 16 of Set 4 | hualmay
# Processing Record 17 of Set 4 | boueni
# Processing Record 18 of Set 4 | ludvika
# Processing Record 19 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 20 of Set 4 | anuppur
# Processing Record 21 of Set 4 | vila velha
# Processing Record 22 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 23 of Set 4 | pangnirtung
# Processing Record 24 of Set 4 | channel-port aux basques
# Processing Record 25 of Set 4 | laval
# Processing Record 26 of Set 4 | victor harbor
# Processing Record 27 of Set 4 | huancavelica
# Processing Record 28 of Set 4 | hibbing
# Processing Record 29 of Set 4 | haines junction
# Processing Record 30 of Set 4 | severo-kurilsk
# Processing Record 31 of Set 4 | sioux lookout
# Processing Record 32 of Set 4 | balikpapan
# Processing Record 33 of Set 4 | cozumel
# Processing Record 34 of Set 4 | rabat
# Processing Record 35 of Set 4 | calama
# Processing Record 36 of Set 4 | skalistyy
# City not found. Skipping...
# Processing Record 37 of Set 4 | obluche
# City not found. Skipping...
# Processing Record 38 of Set 4 | tuktoyaktuk
# Processing Record 39 of Set 4 | lagoa
# Processing Record 40 of Set 4 | baculin
# Processing Record 41 of Set 4 | hofn
# Processing Record 42 of Set 4 | iracoubo
# Processing Record 43 of Set 4 | rio grande
# Processing Record 44 of Set 4 | ivanovskoye
# Processing Record 45 of Set 4 | almaznyy
# Processing Record 46 of Set 4 | beringovskiy
# Processing Record 47 of Set 4 | eyl
# Processing Record 48 of Set 4 | ardistan
# City not found. Skipping...
# Processing Record 49 of Set 4 | kattivakkam
# Processing Record 50 of Set 4 | sitka
# Processing Record 1 of Set 5 | lata
# Processing Record 2 of Set 5 | bogorodskoye
# Processing Record 3 of Set 5 | san patricio
# Processing Record 4 of Set 5 | puerto guzman
# Processing Record 5 of Set 5 | high level
# Processing Record 6 of Set 5 | xining
# Processing Record 7 of Set 5 | chuy
# Processing Record 8 of Set 5 | camopi
# Processing Record 9 of Set 5 | lasa
# Processing Record 10 of Set 5 | malandag
# Processing Record 11 of Set 5 | mar del plata
# Processing Record 12 of Set 5 | itoman
# Processing Record 13 of Set 5 | avera
# Processing Record 14 of Set 5 | mounana
# Processing Record 15 of Set 5 | verkhoyansk
# Processing Record 16 of Set 5 | bulaevo
# Processing Record 17 of Set 5 | batemans bay
# Processing Record 18 of Set 5 | columbia
# Processing Record 19 of Set 5 | bintulu
# Processing Record 20 of Set 5 | komsomolskiy
# Processing Record 21 of Set 5 | linxia
# Processing Record 22 of Set 5 | raudeberg
# Processing Record 23 of Set 5 | arona
# Processing Record 24 of Set 5 | gat
# Processing Record 25 of Set 5 | kruisfontein
# Processing Record 26 of Set 5 | bosaso
# Processing Record 27 of Set 5 | karaton
# Processing Record 28 of Set 5 | balkhash
# Processing Record 29 of Set 5 | tasiilaq
# Processing Record 30 of Set 5 | salalah
# Processing Record 31 of Set 5 | dunedin
# Processing Record 32 of Set 5 | khasan
# Processing Record 33 of Set 5 | sept-iles
# Processing Record 34 of Set 5 | nizhnyaya tavda
# Processing Record 35 of Set 5 | atambua
# Processing Record 36 of Set 5 | kodinsk
# Processing Record 37 of Set 5 | provideniya
# Processing Record 38 of Set 5 | jabiru
# City not found. Skipping...
# Processing Record 39 of Set 5 | hirara
# Processing Record 40 of Set 5 | tual
# Processing Record 41 of Set 5 | byron bay
# Processing Record 42 of Set 5 | mana
# Processing Record 43 of Set 5 | cabedelo
# Processing Record 44 of Set 5 | dikson
# Processing Record 45 of Set 5 | kalmunai
# Processing Record 46 of Set 5 | noshiro
# Processing Record 47 of Set 5 | saint-philippe
# Processing Record 48 of Set 5 | pandan
# Processing Record 49 of Set 5 | narsaq
# Processing Record 50 of Set 5 | gurgan
# City not found. Skipping...
# Processing Record 1 of Set 6 | lebu
# Processing Record 2 of Set 6 | samana
# Processing Record 3 of Set 6 | aban
# Processing Record 4 of Set 6 | santa fe
# Processing Record 5 of Set 6 | san andres
# Processing Record 6 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 7 of Set 6 | ponta do sol
# Processing Record 8 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 9 of Set 6 | tuatapere
# Processing Record 10 of Set 6 | zyryanka
# Processing Record 11 of Set 6 | sao filipe
# Processing Record 12 of Set 6 | north platte
# Processing Record 13 of Set 6 | kalach-na-donu
# Processing Record 14 of Set 6 | grindavik
# Processing Record 15 of Set 6 | karoi
# Processing Record 16 of Set 6 | eureka
# Processing Record 17 of Set 6 | katha
# City not found. Skipping...
# Processing Record 18 of Set 6 | falealupo
# City not found. Skipping...
# Processing Record 19 of Set 6 | filingue
# Processing Record 20 of Set 6 | hokitika
# Processing Record 21 of Set 6 | hidas
# Processing Record 22 of Set 6 | guerrero negro
# Processing Record 23 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 24 of Set 6 | sarkand
# Processing Record 25 of Set 6 | vangaindrano
# Processing Record 26 of Set 6 | dubbo
# Processing Record 27 of Set 6 | fairmont
# Processing Record 28 of Set 6 | cape coast
# Processing Record 29 of Set 6 | iqaluit
# Processing Record 30 of Set 6 | kalabo
# Processing Record 31 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 6 | havre-saint-pierre
# Processing Record 33 of Set 6 | shimoda
# Processing Record 34 of Set 6 | presidencia roque saenz pena
# Processing Record 35 of Set 6 | kazanskaya
# Processing Record 36 of Set 6 | paraiso
# Processing Record 37 of Set 6 | kushiro
# Processing Record 38 of Set 6 | nouadhibou
# Processing Record 39 of Set 6 | sao felix do xingu
# Processing Record 40 of Set 6 | tabuk
# Processing Record 41 of Set 6 | veranopolis
# Processing Record 42 of Set 6 | te anau
# Processing Record 43 of Set 6 | burgeo
# Processing Record 44 of Set 6 | kutum
# Processing Record 45 of Set 6 | kande
# Processing Record 46 of Set 6 | chinsali
# Processing Record 47 of Set 6 | tarudant
# City not found. Skipping...
# Processing Record 48 of Set 6 | bilma
# Processing Record 49 of Set 6 | sangmelima
# Processing Record 50 of Set 6 | faya
# Processing Record 1 of Set 7 | ixtacomitan
# Processing Record 2 of Set 7 | labuhan
# Processing Record 3 of Set 7 | san alberto
# Processing Record 4 of Set 7 | huarmey
# Processing Record 5 of Set 7 | geraldton
# Processing Record 6 of Set 7 | gelemso
# Processing Record 7 of Set 7 | syedove
# Processing Record 8 of Set 7 | aleksandrow kujawski
# Processing Record 9 of Set 7 | dingle
# Processing Record 10 of Set 7 | wazzan
# City not found. Skipping...
# Processing Record 11 of Set 7 | ahuimanu
# Processing Record 12 of Set 7 | clyde river
# Processing Record 13 of Set 7 | ponta delgada
# Processing Record 14 of Set 7 | vanavara
# Processing Record 15 of Set 7 | maningrida
# Processing Record 16 of Set 7 | rocha
# Processing Record 17 of Set 7 | nelson bay
# Processing Record 18 of Set 7 | takhatgarh
# Processing Record 19 of Set 7 | sao jose do calcado
# Processing Record 20 of Set 7 | northam
# Processing Record 21 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 22 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 23 of Set 7 | pevek
# Processing Record 24 of Set 7 | najran
# Processing Record 25 of Set 7 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 26 of Set 7 | luderitz
# Processing Record 27 of Set 7 | korla
# Processing Record 28 of Set 7 | castro
# Processing Record 29 of Set 7 | ola
# Processing Record 30 of Set 7 | belmonte
# Processing Record 31 of Set 7 | klaksvik
# Processing Record 32 of Set 7 | grand centre
# City not found. Skipping...
# Processing Record 33 of Set 7 | tukrah
# Processing Record 34 of Set 7 | saint-francois
# Processing Record 35 of Set 7 | ahipara
# Processing Record 36 of Set 7 | piranhas
# Processing Record 37 of Set 7 | tuburan
# Processing Record 38 of Set 7 | grand gaube
# Processing Record 39 of Set 7 | muriti
# Processing Record 40 of Set 7 | westport
# Processing Record 41 of Set 7 | yerofey pavlovich
# Processing Record 42 of Set 7 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 43 of Set 7 | florence
# Processing Record 44 of Set 7 | sibolga
# Processing Record 45 of Set 7 | hovd
# Processing Record 46 of Set 7 | cabo san lucas
# Processing Record 47 of Set 7 | mangrol
# Processing Record 48 of Set 7 | dolinsk
# Processing Record 49 of Set 7 | karachi
# Processing Record 50 of Set 7 | rubizhne
# Processing Record 1 of Set 8 | ulaanbaatar
# Processing Record 2 of Set 8 | mogadishu
# Processing Record 3 of Set 8 | hamburg
# Processing Record 4 of Set 8 | kenai
# Processing Record 5 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 6 of Set 8 | sun valley
# Processing Record 7 of Set 8 | nouakchott
# Processing Record 8 of Set 8 | yendi
# Processing Record 9 of Set 8 | jablah
# Processing Record 10 of Set 8 | kichera
# Processing Record 11 of Set 8 | bemidji
# Processing Record 12 of Set 8 | clovis
# Processing Record 13 of Set 8 | souillac
# Processing Record 14 of Set 8 | kavieng
# Processing Record 15 of Set 8 | tiksi
# Processing Record 16 of Set 8 | indiaroba
# Processing Record 17 of Set 8 | umm kaddadah
# Processing Record 18 of Set 8 | codrington
# Processing Record 19 of Set 8 | neftcala
# Processing Record 20 of Set 8 | nome
# Processing Record 21 of Set 8 | mugla
# Processing Record 22 of Set 8 | hobyo
# Processing Record 23 of Set 8 | nuuk
# Processing Record 24 of Set 8 | araguaina
# Processing Record 25 of Set 8 | khormuj
# City not found. Skipping...
# Processing Record 26 of Set 8 | buala
# Processing Record 27 of Set 8 | santa rosa
# Processing Record 28 of Set 8 | griffith
# Processing Record 29 of Set 8 | laiyang
# Processing Record 30 of Set 8 | mukhen
# Processing Record 31 of Set 8 | mongoumba
# Processing Record 32 of Set 8 | siocon
# Processing Record 33 of Set 8 | talnakh
# Processing Record 34 of Set 8 | aksarka
# Processing Record 35 of Set 8 | bodaybo
# Processing Record 36 of Set 8 | flin flon
# Processing Record 37 of Set 8 | hay river
# Processing Record 38 of Set 8 | tilichiki
# Processing Record 39 of Set 8 | luklukan
# Processing Record 40 of Set 8 | pacific grove
# Processing Record 41 of Set 8 | tongren
# Processing Record 42 of Set 8 | ayan
# Processing Record 43 of Set 8 | librazhd
# Processing Record 44 of Set 8 | lujan
# Processing Record 45 of Set 8 | sinnamary
# Processing Record 46 of Set 8 | bend
# Processing Record 47 of Set 8 | paso de carrasco
# Processing Record 48 of Set 8 | cidreira
# Processing Record 49 of Set 8 | huambo
# Processing Record 50 of Set 8 | tunxi
# City not found. Skipping...
# Processing Record 1 of Set 9 | manjeshwar
# Processing Record 2 of Set 9 | college
# Processing Record 3 of Set 9 | monrovia
# Processing Record 4 of Set 9 | high prairie
# Processing Record 5 of Set 9 | vanino
# Processing Record 6 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 9 | senanga
# Processing Record 8 of Set 9 | khani
# Processing Record 9 of Set 9 | hailun
# Processing Record 10 of Set 9 | high rock
# Processing Record 11 of Set 9 | kapit
# Processing Record 12 of Set 9 | muros
# Processing Record 13 of Set 9 | meulaboh
# Processing Record 14 of Set 9 | praya
# Processing Record 15 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 16 of Set 9 | great yarmouth
# Processing Record 17 of Set 9 | quatre cocos
# Processing Record 18 of Set 9 | krasnoselkup
# Processing Record 19 of Set 9 | sao gabriel da cachoeira
# Processing Record 20 of Set 9 | pozo colorado
# Processing Record 21 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 22 of Set 9 | marawi
# Processing Record 23 of Set 9 | adamas
# Processing Record 24 of Set 9 | dolzhanskaya
# Processing Record 25 of Set 9 | tura
# Processing Record 26 of Set 9 | nanortalik
# Processing Record 27 of Set 9 | ugoofaaru
# Processing Record 28 of Set 9 | challans
# Processing Record 29 of Set 9 | atasu
# Processing Record 30 of Set 9 | stange
# Processing Record 31 of Set 9 | mitchell
# Processing Record 32 of Set 9 | maldonado
# Processing Record 33 of Set 9 | norman wells
# Processing Record 34 of Set 9 | roald
# Processing Record 35 of Set 9 | ambilobe
# Processing Record 36 of Set 9 | carnarvon
# Processing Record 37 of Set 9 | caxito
# Processing Record 38 of Set 9 | charlestown
# Processing Record 39 of Set 9 | konstantinovka
# Processing Record 40 of Set 9 | puerto escondido
# Processing Record 41 of Set 9 | maasim
# Processing Record 42 of Set 9 | prince george
# Processing Record 43 of Set 9 | turukhansk
# Processing Record 44 of Set 9 | mahadday weyne
# City not found. Skipping...
# Processing Record 45 of Set 9 | ilulissat
# Processing Record 46 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 47 of Set 9 | dongsheng
# Processing Record 48 of Set 9 | surt
# Processing Record 49 of Set 9 | barra
# Processing Record 50 of Set 9 | tierranueva
# Processing Record 1 of Set 10 | victoria
# Processing Record 2 of Set 10 | oxford
# Processing Record 3 of Set 10 | vila franca do campo
# Processing Record 4 of Set 10 | salina
# Processing Record 5 of Set 10 | safut
# Processing Record 6 of Set 10 | chingirlau
# Processing Record 7 of Set 10 | calvia
# Processing Record 8 of Set 10 | gorgan
# Processing Record 9 of Set 10 | christchurch
# Processing Record 10 of Set 10 | maniitsoq
# Processing Record 11 of Set 10 | derzhavinsk
# Processing Record 12 of Set 10 | sarany
# Processing Record 13 of Set 10 | melo
# Processing Record 14 of Set 10 | akranes
# Processing Record 15 of Set 10 | penzance
# Processing Record 16 of Set 10 | salisbury
# Processing Record 17 of Set 10 | selma
# Processing Record 18 of Set 10 | ouesso
# Processing Record 19 of Set 10 | rudnogorsk
# Processing Record 20 of Set 10 | qaqortoq
# Processing Record 21 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 22 of Set 10 | winnemucca
# Processing Record 23 of Set 10 | perevoz
# Processing Record 24 of Set 10 | poum
# Processing Record 25 of Set 10 | jijiga
# Processing Record 26 of Set 10 | moyale
# Processing Record 27 of Set 10 | weligama
# Processing Record 28 of Set 10 | idlib
# Processing Record 29 of Set 10 | arkhara
# Processing Record 30 of Set 10 | petawawa
# Processing Record 31 of Set 10 | toamasina
# Processing Record 32 of Set 10 | taganak
# Processing Record 33 of Set 10 | kroya
# Processing Record 34 of Set 10 | merauke
# Processing Record 35 of Set 10 | laguna de perlas
# Processing Record 36 of Set 10 | bella vista
# Processing Record 37 of Set 10 | waipawa
# Processing Record 38 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 39 of Set 10 | sao joao da barra
# Processing Record 40 of Set 10 | westpunt
# City not found. Skipping...
# Processing Record 41 of Set 10 | bakonyszentlaszlo
# Processing Record 42 of Set 10 | lom
# Processing Record 43 of Set 10 | dudinka
# Processing Record 44 of Set 10 | gotsu
# Processing Record 45 of Set 10 | aykhal
# Processing Record 46 of Set 10 | popondetta
# Processing Record 47 of Set 10 | rivadavia
# Processing Record 48 of Set 10 | imeni poliny osipenko
# Processing Record 49 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 50 of Set 10 | bloomsburg
# Processing Record 1 of Set 11 | taltal
# Processing Record 2 of Set 11 | lazarev
# Processing Record 3 of Set 11 | novovarshavka
# Processing Record 4 of Set 11 | iskateley
# Processing Record 5 of Set 11 | portoferraio
# Processing Record 6 of Set 11 | pemba
# Processing Record 7 of Set 11 | walvis bay
# Processing Record 8 of Set 11 | sampit
# Processing Record 9 of Set 11 | laguna
# Processing Record 10 of Set 11 | abha
# Processing Record 11 of Set 11 | la asuncion
# Processing Record 12 of Set 11 | hasaki
# Processing Record 13 of Set 11 | antofagasta
# Processing Record 14 of Set 11 | katsuura
# Processing Record 15 of Set 11 | wewak
# Processing Record 16 of Set 11 | gberia fotombu
# Processing Record 17 of Set 11 | merrill
# Processing Record 18 of Set 11 | coihaique
# Processing Record 19 of Set 11 | nexo
# Processing Record 20 of Set 11 | prattville
# Processing Record 21 of Set 11 | mount gambier
# Processing Record 22 of Set 11 | messina
# Processing Record 23 of Set 11 | nyurba
# Processing Record 24 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 25 of Set 11 | jumla
# Processing Record 26 of Set 11 | warragul
# Processing Record 27 of Set 11 | kropotkin
# Processing Record 28 of Set 11 | port macquarie
# Processing Record 29 of Set 11 | berlevag
# Processing Record 30 of Set 11 | santa lucia
# Processing Record 31 of Set 11 | matara
# Processing Record 32 of Set 11 | road town
# Processing Record 33 of Set 11 | moose factory
# Processing Record 34 of Set 11 | soe
# Processing Record 35 of Set 11 | cairns
# Processing Record 36 of Set 11 | kostino
# Processing Record 37 of Set 11 | kirakira
# Processing Record 38 of Set 11 | sangar
# Processing Record 39 of Set 11 | tuggurt
# City not found. Skipping...
# Processing Record 40 of Set 11 | deputatskiy
# Processing Record 41 of Set 11 | xuddur
# Processing Record 42 of Set 11 | sisimiut
# Processing Record 43 of Set 11 | touros
# Processing Record 44 of Set 11 | yanggu
# Processing Record 45 of Set 11 | corral nuevo
# Processing Record 46 of Set 11 | aitape
# Processing Record 47 of Set 11 | samfya
# Processing Record 48 of Set 11 | harlingen
# Processing Record 49 of Set 11 | beyneu
# Processing Record 50 of Set 11 | itarema
# Processing Record 1 of Set 12 | vila do maio
# Processing Record 2 of Set 12 | orapa
# Processing Record 3 of Set 12 | pondicherry
# Processing Record 4 of Set 12 | mabaruma
# Processing Record 5 of Set 12 | plettenberg bay
# Processing Record 6 of Set 12 | garden city
# Processing Record 7 of Set 12 | belen
# Processing Record 8 of Set 12 | louga
# Processing Record 9 of Set 12 | ancud
# Processing Record 10 of Set 12 | half moon bay
# Processing Record 11 of Set 12 | fortuna
# Processing Record 12 of Set 12 | yuncheng
# Processing Record 13 of Set 12 | singleton
# Processing Record 14 of Set 12 | ulladulla
# Processing Record 15 of Set 12 | lampazos de naranjo
# Processing Record 16 of Set 12 | yarada
# Processing Record 17 of Set 12 | port pirie
# Processing Record 18 of Set 12 | san cristobal
# Processing Record 19 of Set 12 | ukiah
# Processing Record 20 of Set 12 | umm lajj
# Processing Record 21 of Set 12 | kuching
# Processing Record 22 of Set 12 | coahuayana
# Processing Record 23 of Set 12 | constitucion
# Processing Record 24 of Set 12 | nisia floresta
# Processing Record 25 of Set 12 | cururupu
# Processing Record 26 of Set 12 | vaxjo
# Processing Record 27 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 28 of Set 12 | tangzhai
# Processing Record 29 of Set 12 | vilhena
# Processing Record 30 of Set 12 | paamiut
# Processing Record 31 of Set 12 | asau
# Processing Record 32 of Set 12 | hervey bay
# Processing Record 33 of Set 12 | pontianak
# Processing Record 34 of Set 12 | sanghar
# Processing Record 35 of Set 12 | manokwari
# Processing Record 36 of Set 12 | yumen
# Processing Record 37 of Set 12 | marienburg
# Processing Record 38 of Set 12 | carutapera
# Processing Record 39 of Set 12 | novaya bryan
# Processing Record 40 of Set 12 | naze
# Processing Record 41 of Set 12 | bonavista
# Processing Record 42 of Set 12 | baykit
# Processing Record 43 of Set 12 | kaeo
# Processing Record 44 of Set 12 | iquique
# Processing Record 45 of Set 12 | black river
# Processing Record 46 of Set 12 | kosonsoy
# Processing Record 47 of Set 12 | kankon
# Processing Record 48 of Set 12 | cedral
# Processing Record 49 of Set 12 | atherton
# Processing Record 50 of Set 12 | santa isabel
# Processing Record 1 of Set 13 | vestmanna
# Processing Record 2 of Set 13 | camacha
# Processing Record 3 of Set 13 | sembe
# Processing Record 4 of Set 13 | jahrom
# City not found. Skipping...
# Processing Record 5 of Set 13 | mount kisco
# Processing Record 6 of Set 13 | vermilion
# Processing Record 7 of Set 13 | korem
# Processing Record 8 of Set 13 | isperih
# Processing Record 9 of Set 13 | roma
# Processing Record 10 of Set 13 | abu zabad
# Processing Record 11 of Set 13 | torrington
# Processing Record 12 of Set 13 | oussouye
# Processing Record 13 of Set 13 | la ronge
# Processing Record 14 of Set 13 | vostok
# Processing Record 15 of Set 13 | adre
# Processing Record 16 of Set 13 | lompoc
# Processing Record 17 of Set 13 | lo arado
# Processing Record 18 of Set 13 | bardiyah
# Processing Record 19 of Set 13 | saint-pierre
# Processing Record 20 of Set 13 | alakurtti
# Processing Record 21 of Set 13 | karakendzha
# City not found. Skipping...
# Processing Record 22 of Set 13 | nata
# Processing Record 23 of Set 13 | tasbuget
# City not found. Skipping...
# Processing Record 24 of Set 13 | smithers
# Processing Record 25 of Set 13 | harper
# Processing Record 26 of Set 13 | samusu
# City not found. Skipping...
# Processing Record 27 of Set 13 | yarkovo
# Processing Record 28 of Set 13 | boyolangu
# Processing Record 29 of Set 13 | chipinge
# Processing Record 30 of Set 13 | collie
# Processing Record 31 of Set 13 | constantine
# Processing Record 32 of Set 13 | uvira
# Processing Record 33 of Set 13 | vozdvizhenka
# Processing Record 34 of Set 13 | port-gentil
# Processing Record 35 of Set 13 | kingaroy
# Processing Record 36 of Set 13 | ust-ilimsk
# Processing Record 37 of Set 13 | dourbali
# Processing Record 38 of Set 13 | rantepao
# Processing Record 39 of Set 13 | qafsah
# City not found. Skipping...
# Processing Record 40 of Set 13 | cascais
# Processing Record 41 of Set 13 | ferkessedougou
# Processing Record 42 of Set 13 | zawiercie
# Processing Record 43 of Set 13 | nishihara
# Processing Record 44 of Set 13 | bubaque
# Processing Record 45 of Set 13 | san isidro
# Processing Record 46 of Set 13 | mahon
# Processing Record 47 of Set 13 | zboriv
# Processing Record 48 of Set 13 | leninsk
# Processing Record 49 of Set 13 | canutama
# Processing Record 50 of Set 13 | owando
# Processing Record 1 of Set 14 | barcelos
# Processing Record 2 of Set 14 | elizabeth city
# Processing Record 3 of Set 14 | kegayli
# City not found. Skipping...
# Processing Record 4 of Set 14 | homer
# Processing Record 5 of Set 14 | palmer
# Processing Record 6 of Set 14 | orje
# Processing Record 7 of Set 14 | okhotsk
# Processing Record 8 of Set 14 | semme
# Processing Record 9 of Set 14 | cortez
# Processing Record 10 of Set 14 | ribeira brava
# Processing Record 11 of Set 14 | san ramon de la nueva oran
# Processing Record 12 of Set 14 | biak
# Processing Record 13 of Set 14 | kampot
# Processing Record 14 of Set 14 | novo oriente
# Processing Record 15 of Set 14 | paducah
# Processing Record 16 of Set 14 | santa maria
# Processing Record 17 of Set 14 | tiruvottiyur
# City not found. Skipping...
# Processing Record 18 of Set 14 | beira
# Processing Record 19 of Set 14 | nantucket
# Processing Record 20 of Set 14 | bandarbeyla
# Processing Record 21 of Set 14 | belem de sao francisco
# Processing Record 22 of Set 14 | margate
# Processing Record 23 of Set 14 | north bend
# Processing Record 24 of Set 14 | laranjeiras do sul
# Processing Record 25 of Set 14 | ajdabiya
# Processing Record 26 of Set 14 | sungairaya
# Processing Record 27 of Set 14 | koutsouras
# Processing Record 28 of Set 14 | zilair
# Processing Record 29 of Set 14 | matay
# Processing Record 30 of Set 14 | nioro
# Processing Record 31 of Set 14 | nizhniy tsasuchey
# Processing Record 32 of Set 14 | oxapampa
# Processing Record 33 of Set 14 | damascus
# Processing Record 34 of Set 14 | isangel
# Processing Record 35 of Set 14 | bowen
# Processing Record 36 of Set 14 | sakakah
# Processing Record 37 of Set 14 | havelock
# Processing Record 38 of Set 14 | kathu
# Processing Record 39 of Set 14 | beloha
# Processing Record 40 of Set 14 | elat
# Processing Record 41 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 42 of Set 14 | oistins
# Processing Record 43 of Set 14 | yinchuan
# Processing Record 44 of Set 14 | rawson
# Processing Record 45 of Set 14 | labuan
# Processing Record 46 of Set 14 | tombouctou
# Processing Record 47 of Set 14 | rosetta
# Processing Record 48 of Set 14 | garm
# City not found. Skipping...
# Processing Record 49 of Set 14 | ust-ordynskiy
# Processing Record 50 of Set 14 | saryozek
# Processing Record 1 of Set 15 | bathsheba
# Processing Record 2 of Set 15 | nabire
# Processing Record 3 of Set 15 | esmeraldas
# Processing Record 4 of Set 15 | araouane
# Processing Record 5 of Set 15 | san pedro de macoris
# Processing Record 6 of Set 15 | outlook
# Processing Record 7 of Set 15 | gillette
# Processing Record 8 of Set 15 | marrakesh
# Processing Record 9 of Set 15 | greencastle
# Processing Record 10 of Set 15 | vardo
# Processing Record 11 of Set 15 | myitkyina
# Processing Record 12 of Set 15 | canhotinho
# Processing Record 13 of Set 15 | brigantine
# Processing Record 14 of Set 15 | visnes
# Processing Record 15 of Set 15 | suntar
# Processing Record 16 of Set 15 | sobolevo
# Processing Record 17 of Set 15 | dunda
# Processing Record 18 of Set 15 | ozernovskiy
# Processing Record 19 of Set 15 | swanzey
# Processing Record 20 of Set 15 | awbari
# Processing Record 21 of Set 15 | ngaoundere
# Processing Record 22 of Set 15 | irbeyskoye
# Processing Record 23 of Set 15 | jelah
# Processing Record 24 of Set 15 | conde
# Processing Record 25 of Set 15 | bolbosi
# Processing Record 26 of Set 15 | young
# Processing Record 27 of Set 15 | karatau
# Processing Record 28 of Set 15 | el rosario
# Processing Record 29 of Set 15 | uwayl
# City not found. Skipping...
# Processing Record 30 of Set 15 | voyvozh
# Processing Record 31 of Set 15 | luanda
# Processing Record 32 of Set 15 | tuy hoa
# Processing Record 33 of Set 15 | izhma
# Processing Record 34 of Set 15 | muravlenko
# Processing Record 35 of Set 15 | yurga
# Processing Record 36 of Set 15 | lamlash
# Processing Record 37 of Set 15 | buchanan
# Processing Record 38 of Set 15 | jalu
# Processing Record 39 of Set 15 | namibe
# Processing Record 40 of Set 15 | port hardy
# Processing Record 41 of Set 15 | igarka
# Processing Record 42 of Set 15 | kupang
# Processing Record 43 of Set 15 | fevralsk
# City not found. Skipping...
# Processing Record 44 of Set 15 | bani
# Processing Record 45 of Set 15 | ureki
# Processing Record 46 of Set 15 | tapes
# Processing Record 47 of Set 15 | karratha
# Processing Record 48 of Set 15 | teguldet
# Processing Record 49 of Set 15 | innerleithen
# Processing Record 50 of Set 15 | fayaoue
# Processing Record 1 of Set 16 | praia
# Processing Record 2 of Set 16 | kiama
# Processing Record 3 of Set 16 | dallas
# Processing Record 4 of Set 16 | comodoro rivadavia
# Processing Record 5 of Set 16 | prado
# Processing Record 6 of Set 16 | gravelbourg
# Processing Record 7 of Set 16 | tazovskiy
# Processing Record 8 of Set 16 | pochutla
# Processing Record 9 of Set 16 | vammala
# Processing Record 10 of Set 16 | usinsk
# Processing Record 11 of Set 16 | causapscal
# Processing Record 12 of Set 16 | altamira
# Processing Record 13 of Set 16 | peniche
# Processing Record 14 of Set 16 | chumikan
# Processing Record 15 of Set 16 | rancharia
# Processing Record 16 of Set 16 | ondorhaan
# City not found. Skipping...
# Processing Record 17 of Set 16 | aginskoye
# Processing Record 18 of Set 16 | verkhnevilyuysk
# Processing Record 19 of Set 16 | trogir
# Processing Record 20 of Set 16 | atakpame
# Processing Record 21 of Set 16 | moron
# Processing Record 22 of Set 16 | brownsville
# Processing Record 23 of Set 16 | villarrica
# Processing Record 24 of Set 16 | rabo de peixe
# Processing Record 25 of Set 16 | burns lake
# Processing Record 26 of Set 16 | abu dhabi
# Processing Record 27 of Set 16 | mount isa
# Processing Record 28 of Set 16 | artyom
# Processing Record 29 of Set 16 | ondangwa
# Processing Record 30 of Set 16 | sudzha
# Processing Record 31 of Set 16 | ouango
# Processing Record 32 of Set 16 | mataram
# Processing Record 33 of Set 16 | barsovo
# Processing Record 34 of Set 16 | padang
# Processing Record 35 of Set 16 | ust-tsilma
# Processing Record 36 of Set 16 | corner brook
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Aklavik  68.2191 -135.0107     -8.57        77          90
# 1       Talcahuano -36.7167  -73.1167     69.48        64           0
# 2  Bambous Virieux -20.3428   57.7575     74.21        88          20
# 3        Hithadhoo  -0.6000   73.0833     81.55        73         100
# 4         Flinders -34.5833  150.8552     84.06        60         100
# 5          Mataura -46.1927  168.8643     73.47        42          93
# 6      Yellowknife  62.4560 -114.3525    -13.59        95          75
# 7          Ushuaia -54.8000  -68.3000     64.06        45          20
# 8            Vaini -21.2000 -175.2000     84.36        94          40
# 9         Hamilton  39.1834  -84.5333     43.09        92         100
#
#    Wind Speed Country Current Description
# 0        0.00      CA          light snow
# 1       12.66      CL           clear sky
# 2        3.44      MU          few clouds
# 3        3.11      MV     overcast clouds
# 4        8.12      AU     overcast clouds
# 5       13.09      NZ     overcast clouds
# 6        4.61      CA   light shower snow
# 7       18.41      AR          few clouds
# 8        9.22      TO          light rain
# 9        4.00      US     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
